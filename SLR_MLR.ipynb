# %% [markdown]
# <a href="https://colab.research.google.com/github/D-Sritha-D/AIML_Basics_Avanthi/blob/main/SLR_MLR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Machine Learning**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Alright, imagine you have a magical robot friend who loves to learn and get smarter every day. This cool buddy, let's call it RoboBrain, has a superpower called "Machine Learning"!
#
# So, instead of being programmed with every single detail, RoboBrain learns from experience and examples, just like how you learn to ride a bike by practicing and not by reading a bicycle manual cover to cover. Machine learning is like giving RoboBrain the ability to observe, adapt, and improve itself over time.
#
# It's like teaching your pet parrot to talk, but on a whole new level! RoboBrain doesn't just repeat phrases; it understands patterns, makes predictions, and becomes a genius in tasks it wasn't explicitly taught. It's like having a digital apprentice that evolves and becomes a wizard of knowledge!
#
# So, in a nutshell, machine learning is like having a high-tech apprentice that learns from the world and becomes the Dumbledore of data! 🧙‍♂️🤖

# %% [markdown]
# # **Dealing with the Data**

# %% [markdown]
# To analyze data, it is important to know what type of data we are dealing with.
#
# We can split the data types into three main categories:
# *   Numerical
# *   Categorical
# *   Ordinal
#
# **Numerical data** are numbers, and can be split into two numerical categories:
# Discrete Data
# - counted data that are limited to integers. Example: The number of cars passing by.
#
# Continuous Data
# - measured data that can be any number. Example: The price of an item, or the size of an item
#
# **Categorical data** are values that cannot be measured up against each other. Example: a color value, or any yes/no values.
#
# **Ordinal data** are like categorical data, but can be measured up against each other. Example: school grades where A is better than B and so on.

# %% [markdown]
# # **Looking into some important Stats**

# %%
import numpy as np
a = np.array([16,6,21,5.5,6.7,8.9])

# %%
# Calculating the mean
np.mean(a)
# Out:
# 10.683333333333335

# %%
# Calculating the median
np.median(a)
# Out:
# 7.800000000000001

# %%
# Calculating the mode
from scipy import stats
x = stats.mode(a)
x
# Out:
# ModeResult(mode=5.5, count=1)

# %%
# Calculating the standard deviation
np.std(a)
# Out:
# 5.810168289779183

# %%
# Calculating the variance
np.var(a)
# Out:
# 33.75805555555555

# %% [markdown]
# Standard Deviation is often represented by the symbol Sigma: **σ**
#
# Variance is often represented by the symbol Sigma Squared: **σ^2**

# %% [markdown]
# # **Supervised vs. Unsupervised vs. Semi-Supervised Learning**

# %% [markdown]
# | Aspect                  | Supervised Learning                           | Unsupervised Learning                             | Semi-Supervised Learning                        |
# |-------------------------|------------------------------------------------|---------------------------------------------------|------------------------------------------------|
# | Training Data           | Labeled data                                   | Unlabeled data                                    | Combination of labeled and unlabeled data       |
# | Objective               | Predicts the output based on input-output pairs| Extracts patterns or structures from input data  | Combination of prediction and pattern discovery|
# | Examples                | Classification, Regression                    | Clustering, Dimensionality Reduction              | Generative models, Anomaly Detection            |
# | Algorithm Examples      | Decision Trees, Support Vector Machines        | K-means, Hierarchical Clustering                  | Self-training, Co-training                      |
# | Input-Output Relationship| Input and corresponding output provided        | No explicit input-output relationship provided    | Partial input-output relationship available    |
# | Human Intervention      | High (labels provided by humans)               | Low (no need for labeled data, less supervision)  | Moderate (partially labeled, requires effort)  |

# %% [markdown]
# | Learning Type          | Description                                                                                        | Examples                                                      |
# |------------------------|----------------------------------------------------------------------------------------------------|---------------------------------------------------------------|
# | Supervised Learning    | - Learning with labeled data where the algorithm learns from input-output pairs.                   | - Email spam classification<br>- Handwritten digit recognition |
# |                        | - The algorithm aims to map input data to the correct output during training.                       |                                                               |
# | Unsupervised Learning  | - Learning with unlabeled data where the algorithm tries to find patterns or structures.           | - Clustering customer segments<br>- Anomaly detection         |
# |                        | - The algorithm explores the data and identifies relationships without explicit guidance.           |                                                               |
# | Semi-supervised Learning | - Learning with a combination of labeled and unlabeled data, leveraging both types of information. | - Document categorization with limited labeled data            |
# |                         | - The algorithm uses the small set of labeled data and the larger set of unlabeled data to improve performance. |                                                              |
# | Reinforcement Learning | - Learning through interaction with an environment where the algorithm aims to maximize rewards.    | - Training game-playing agents<br>- Robotics control          |
# |                        | - The algorithm takes actions in an environment and learns from the feedback (rewards or penalties). |                                                               |

# %% [markdown]
# # **Classification & Regression**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Classifier**- Algorithm used to map the input data to a specific category
#
# **Classification Model** - Model that predicts or draws a class to the input data given for training
#
# **Feature** - Individual measurable property of the phenomenon being measured
#
# **Labels** - Characteristics on whci hthe datapoints of the dataset are categorized
#
# **Clusters** - Group of datapoints which have some common characteristics
#
# **Binary Classification** - Has only 2 outcomes
#
# **Multi-Label Classification** - Classification Condition where each sample is assigned to a set of labels or targets
#
# **Multi-Class Classification** - Has more than 2 classes. Here each sample is assigned to one and only one label.

# %% [markdown]
# ### **Classification Real World Examples**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Types of Classification Algorithms**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# | Aspect                  | Classification                                   | Regression                                       |
# |-------------------------|--------------------------------------------------|--------------------------------------------------|
# | Nature of Output        | Categorical                                      | Continuous                                      |
# | Goal                    | Predict class labels                             | Predict numerical values                        |
# | Examples                | Spam detection, Image classification             | House price prediction, Stock price forecasting |
# | Output Representation   | Class labels or probabilities                    | Continuous values                               |
# | Evaluation Metrics      | Accuracy, Precision, Recall, F1-score            | Mean Squared Error (MSE), Mean Absolute Error (MAE), R-squared |
# | Common Algorithms       | Logistic Regression, Decision Trees, SVM         | Linear Regression, Polynomial Regression, Random Forests |
# |                        | Random Forests, Neural Networks                  |                                                  |

# %% [markdown]
# # **Simple Linear Regression**

# %% [markdown]
# *   Dependant and Independant Variable
# *   Positive and Negative Sloped Linear Regression Lines

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/content/homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='+')

# %%
X = df.drop('price',axis='columns')
X
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
y = df.price
y
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
# Create linear regression object
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[3300]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
model.intercept_
# Out:
# 180616.43835616432

# %%
d = pd.read_csv('/content/areas.csv')
d.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
p = model.predict(d)

# %%
d['prices'] = p

# %%
d.to_csv('prediction.csv', index=False)

# %%
d = pd.read_csv('/content/prediction.csv')
d
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('prices')
plt.scatter(df.area,df.price,color='red',marker='+')
plt.plot(d.area, model.predict(d[['area']]),color = 'blue')

# %% [markdown]
# ### **Canada Per Capita Income Exercise**

# %%
df = pd.read_csv('/content/canada_per_capita_income.csv')
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
plt.xlabel('Year')
plt.ylabel('Per Capita Income')
plt.scatter(df['year'],df['per capita income (US$)'],color='red',marker='o')
plt.show()

# %%
X = df.drop('per capita income (US$)', axis = 'columns')
X
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
y = df['per capita income (US$)']
y
# Out:
# 0      3399.299037
# 1      3768.297935
# 2      4251.175484
# 3      4804.463248
# 4      5576.514583
# 5      5998.144346
# 6      7062.131392
# 7      7100.126170
# 8      7247.967035
# 9      7602.912681
# 10     8355.968120
# 11     9434.390652
# 12     9619.438377
# 13    10416.536590
# 14    10790.328720
# 15    11018.955850
# 16    11482.891530
# 17    12974.806620
# 18    15080.283450
# 19    16426.725480
# 20    16838.673200
# 21    17266.097690
# 22    16412.083090
# 23    15875.586730
# 24    15755.820270
# 25    16369.317250
# 26    16699.826680
# 27    17310.757750
# 28    16622.671870
# 29    17581.024140
# 30    18987.382410
# 31    18601.397240
# 32    19232.175560
# 33    22739.426280
# 34    25719.147150
# 35    29198.055690
# 36    32738.262900
# 37    36144.481220
# 38    37446.486090
# 39    32755.176820
# 40    38420.522890
# 41    42334.711210
# 42    42665.255970
# 43    42676.468370
# 44    41039.893600
# 45    35175.188980
# 46    34229.193630
# ...

# %%
model2 = LinearRegression()
model2.fit(X,y)
# Out:
# LinearRegression()

# %%
model2.predict([[2024]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([44602.55439531])

# %%
model2.score(X,y)
# Out:
# 0.890916917957032

# %%
model2.coef_
# Out:
# array([828.46507522])

# %%
model.intercept_
# Out:
# 180616.43835616432

# %% [markdown]
# ### **Gradient Descent and Cost Function**

# %% [markdown]
# **Cost Function:**
# A cost function, also known as a loss function or objective function, is a measure of the error or discrepancy between the predicted values of the model and the actual values in the training data.
#
# *Purpose:* The primary purpose of the cost function is to quantify how well or poorly the model is performing on the training data. The goal of training a machine learning model is to minimize the cost function.
#
# **Gradient Descent** is an optimization algorithm used to minimize the cost function during the training of machine learning models. It's a first-order iterative optimization algorithm that finds the minimum of a function by taking iterative steps in the direction of the steepest descent of the function.
#
# [Gradient Descent Visualizer](https://uclaacm.github.io/gradient-descent-visualiser/#playground)
#
# Understanding Derivatives:
# https://www.mathsisfun.com/calculus/derivatives-introduction.html
#
# Understanding Partial Derivatives: https://www.mathsisfun.com/calculus/derivatives-partial.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Learning Rate**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# y=2x+3
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

# %%
def gradient_descent(x,y):
  m_curr = b_curr = 0
  iterations = 1000
  n = len(x)
  learning_rate = 0.001
  for i in range(iterations):
    y_predicted = m_curr*x + b_curr
    cost = (1/n)*sum([val**2 for val in (y-y_predicted)])
    md = -(2/n)*sum(x*(y-y_predicted))
    bd = -(2/n)*sum(y-y_predicted)
    m_curr = m_curr - learning_rate*md
    b_curr = b_curr - learning_rate*bd
    print("m {}, b {}, iteration {}, cost {}".format(m_curr,b_curr,i, cost))

gradient_descent(x,y)

# %% [markdown]
# ### **Dummy Values and One Hot Encoding**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df = pd.read_csv('/content/homesprices_gd.csv')
df
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
dummies = pd.get_dummies(df['town'])
dummies
# Out:
#     monroe township  robinsville  west windsor
# 0                 1            0             0
# 1                 1            0             0
# 2                 1            0             0
# 3                 1            0             0
# 4                 1            0             0
# 5                 0            0             1
# 6                 0            0             1
# 7                 0            0             1
# 8                 0            0             1
# 9                 0            1             0
# 10                0            1             0
# 11                0            1             0
# 12                0            1             0

# %%
merged = pd.concat([df,dummies], axis='columns')
merged
# Out:
#                town  area   price  monroe township  robinsville  west windsor
# 0   monroe township  2600  550000                1            0             0
# 1   monroe township  3000  565000                1            0             0
# 2   monroe township  3200  610000                1            0             0
# 3   monroe township  3600  680000                1            0             0
# 4   monroe township  4000  725000                1            0             0
# 5      west windsor  2600  585000                0            0             1
# 6      west windsor  2800  615000                0            0             1
# 7      west windsor  3300  650000                0            0             1
# 8      west windsor  3600  710000                0            0             1
# 9       robinsville  2600  575000                0            1             0
# 10      robinsville  2900  600000                0            1             0
# ...

# %% [markdown]
# **Dummy Variable Trap:**
#
# When you can derive one variable from other variables, they are known to be multi-colinear. Here if you know values of california and georgia then you can easily infer value of new jersey state, i.e. california=0 and georgia=0. There for these state variables are called to be multi-colinear. In this situation linear regression won't work as expected. Hence you need to drop one column.
#
# **NOTE:** sklearn library takes care of dummy variable trap hence even if you don't drop one of the state columns it is going to work, however we should make a habit of taking care of dummy variable trap ourselves just in case library that you are using is not handling this for you

# %%
final = merged.drop(['town', 'west windsor'], axis='columns')
final
# Out:
#     area   price  monroe township  robinsville
# 0   2600  550000                1            0
# 1   3000  565000                1            0
# 2   3200  610000                1            0
# 3   3600  680000                1            0
# 4   4000  725000                1            0
# 5   2600  585000                0            0
# 6   2800  615000                0            0
# 7   3300  650000                0            0
# 8   3600  710000                0            0
# 9   2600  575000                0            1
# 10  2900  600000                0            1
# 11  3100  620000                0            1
# 12  3600  695000                0            1

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
X = final.drop(['price'], axis='columns')
y = final['price']

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[3333,0,0]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([672739.53988389])

# %%
final
# Out:
#     area   price  monroe township  robinsville
# 0   2600  550000                1            0
# 1   3000  565000                1            0
# 2   3200  610000                1            0
# 3   3600  680000                1            0
# 4   4000  725000                1            0
# 5   2600  585000                0            0
# 6   2800  615000                0            0
# 7   3300  650000                0            0
# 8   3600  710000                0            0
# 9   2600  575000                0            1
# 10  2900  600000                0            1
# 11  3100  620000                0            1
# 12  3600  695000                0            1

# %%
model.score(X,y)
# Out:
# 0.9573929037221872

# %%
model.predict([[3400,0,0]]) # 3400 sqr ft home in west windsor
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([681241.66845839])

# %%
model.predict([[2800,0,1]]) # 2800 sqr ft home in robbinsville
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([590775.63964739])

# %% [markdown]
# Using sklearn OneHotEncoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dfle = df
dfle.town = le.fit_transform(dfle.town)
dfle
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
X = dfle[['town','area']].values
X
# Out:
# array([[   0, 2600],
#        [   0, 3000],
#        [   0, 3200],
#        [   0, 3600],
#        [   0, 4000],
#        [   2, 2600],
#        [   2, 2800],
#        [   2, 3300],
#        [   2, 3600],
#        [   1, 2600],
#        [   1, 2900],
#        [   1, 3100],
#        [   1, 3600]])

# %%
y = dfle.price.values
y
# Out:
# array([550000, 565000, 610000, 680000, 725000, 585000, 615000, 650000,
#        710000, 575000, 600000, 620000, 695000])

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([('town', OneHotEncoder(), [0])], remainder = 'passthrough')

# %%
X = ct.fit_transform(X)
X
# Out:
# array([[1.0e+00, 0.0e+00, 0.0e+00, 2.6e+03],
#        [1.0e+00, 0.0e+00, 0.0e+00, 3.0e+03],
#        [1.0e+00, 0.0e+00, 0.0e+00, 3.2e+03],
#        [1.0e+00, 0.0e+00, 0.0e+00, 3.6e+03],
#        [1.0e+00, 0.0e+00, 0.0e+00, 4.0e+03],
#        [0.0e+00, 0.0e+00, 1.0e+00, 2.6e+03],
#        [0.0e+00, 0.0e+00, 1.0e+00, 2.8e+03],
#        [0.0e+00, 0.0e+00, 1.0e+00, 3.3e+03],
#        [0.0e+00, 0.0e+00, 1.0e+00, 3.6e+03],
#        [0.0e+00, 1.0e+00, 0.0e+00, 2.6e+03],
#        [0.0e+00, 1.0e+00, 0.0e+00, 2.9e+03],
#        [0.0e+00, 1.0e+00, 0.0e+00, 3.1e+03],
#        [0.0e+00, 1.0e+00, 0.0e+00, 3.6e+03]])

# %%
X = X[:,1:]
X
# Out:
# array([[0.0e+00, 0.0e+00, 2.6e+03],
#        [0.0e+00, 0.0e+00, 3.0e+03],
#        [0.0e+00, 0.0e+00, 3.2e+03],
#        [0.0e+00, 0.0e+00, 3.6e+03],
#        [0.0e+00, 0.0e+00, 4.0e+03],
#        [0.0e+00, 1.0e+00, 2.6e+03],
#        [0.0e+00, 1.0e+00, 2.8e+03],
#        [0.0e+00, 1.0e+00, 3.3e+03],
#        [0.0e+00, 1.0e+00, 3.6e+03],
#        [1.0e+00, 0.0e+00, 2.6e+03],
#        [1.0e+00, 0.0e+00, 2.9e+03],
#        [1.0e+00, 0.0e+00, 3.1e+03],
#        [1.0e+00, 0.0e+00, 3.6e+03]])

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[0,1,3400]]) # 3400 sqr ft home in west windsor
# Out:
# array([681241.6684584])

# %%
model.predict([[1,0,2800]]) # 2800 sqr ft home in robbinsville
# Out:
# array([590775.63964739])

# %% [markdown]
# Exercise
# At the same level as this notebook on github, there is an Exercise folder that contains carprices.csv. This file has car sell prices for 3 different models. First plot data points on a scatter plot chart to see if linear regression model can be applied. If yes, then build a model that can answer following questions,
#
# 1) Predict price of a mercedez benz that is 4 yr old with mileage 45000
#
# 2) Predict price of a BMW X5 that is 7 yr old with mileage 86000
#
# 3) Tell me the score (accuracy) of your model. (Hint: use LinearRegression().score())

# %% [markdown]
# # **Multi Linear Regression**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Importing the dataset and Extracting the Independent and Dependent variables
companies = pd.read_csv('1000_Companies.csv')
X = companies.iloc[:, :-1].values
y = companies.iloc[:, 4].values

# %%
companies.head()

# %%
# Data Visualisation
# Building the Correlation matrix
sns.heatmap(companies.corr())

# %%
# Encoding categorical data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder = LabelEncoder()
X[:, 3] = labelencoder.fit_transform(X[:, 3])
onehotencoder = OneHotEncoder(categorical_features = [3])
X = onehotencoder.fit_transform(X).toarray()

# %%
# Avoiding the Dummy Variable Trap
X = X[:, 1:]

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# %%
# Predicting the Test set results
y_pred = regressor.predict(X_test)
y_pred

# %%
# Calculating the Coefficients
print(regressor.coef_)

# %%
# Calculating the Intercept
print(regressor.intercept_)

# %%
# Calculating the R squared value
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
